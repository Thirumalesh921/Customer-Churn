# %%
import pandas as pd

# %%
data=pd.read_csv('Customer_Data.csv')

# %%
data
# Out:
#      Customer_ID  Gender  Age Married          State  Number_of_Referrals  \
# 0      19877-DEL    Male   35      No          Delhi                    7
# 1      58353-MAH  Female   45     Yes    Maharashtra                   14
# 2      25063-WES    Male   51      No    West Bengal                    4
# 3      59787-KAR    Male   79      No      Karnataka                    3
# 4      28544-TAM  Female   80      No     Tamil Nadu                    3
# ...          ...     ...  ...     ...            ...                  ...
# 6413   43397-UTT  Female   41      No  Uttar Pradesh                    6
# 6414   22240-HAR    Male   51     Yes        Haryana                    0
# 6415   78682-KER  Female   65     Yes         Kerala                   14
# 6416   17816-ODI    Male   23      No         Odisha                    2
# 6417   34476-TAM    Male   73      No     Tamil Nadu                   13
#
#       Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  6418 non-null   object
#  1   Gender                       6418 non-null   object
#  2   Age                          6418 non-null   int64
#  3   Married                      6418 non-null   object
#  4   State                        6418 non-null   object
#  5   Number_of_Referrals          6418 non-null   int64
#  6   Tenure_in_Months             6418 non-null   int64
#  7   Value_Deal                   2870 non-null   object
#  8   Phone_Service                6418 non-null   object
#  9   Multiple_Lines               5796 non-null   object
#  10  Internet_Service             6418 non-null   object
#  11  Internet_Type                5028 non-null   object
#  12  Online_Security              5028 non-null   object
# ...

# %%
data['Multiple_Lines']=data['Multiple_Lines'].fillna('No')

# %%
data['Churn_Category']=data['Churn_Category'].fillna('Others')

# %%
data[['Internet_Type','Online_Security','Unlimited_Data','Online_Backup','Device_Protection_Plan','Premium_Support','Streaming_TV','Streaming_Movies','Streaming_Music','Unlimited_Data']]
# Out:
#      Internet_Type Online_Security Unlimited_Data Online_Backup  \
# 0            Cable              No            Yes           Yes
# 1            Cable              No             No            No
# 2      Fiber Optic              No            Yes            No
# 3      Fiber Optic              No            Yes           Yes
# 4      Fiber Optic              No            Yes            No
# ...            ...             ...            ...           ...
# 6413   Fiber Optic              No            Yes            No
# 6414           DSL             Yes            Yes           Yes
# 6415   Fiber Optic              No            Yes            No
# 6416           DSL              No            Yes           Yes
# 6417   Fiber Optic              No            Yes            No
#
#      Device_Protection_Plan Premium_Support Streaming_TV Streaming_Movies  \
# 0                        No             Yes          Yes               No
# ...

# %%
data['Internet_Type']=data['Internet_Type'].fillna('No Internet')
data['Online_Security']=data['Online_Security'].fillna('No')
data['Online_Backup']=data['Online_Backup'].fillna('No')
data['Device_Protection_Plan']=data['Device_Protection_Plan'].fillna('No')
data['Premium_Support']=data['Premium_Support'].fillna('No')
data['Streaming_TV']=data['Streaming_TV'].fillna('No')
data['Unlimited_Data']=data['Unlimited_Data'].fillna('No')
data['Streaming_Movies']=data['Streaming_Movies'].fillna('No')
data['Streaming_Music']=data['Streaming_Music'].fillna('No')
data['Value_Deal']=data['Value_Deal'].fillna('No deals')

# %%
data
# Out:
#      Customer_ID  Gender  Age Married          State  Number_of_Referrals  \
# 0      19877-DEL    Male   35      No          Delhi                    7
# 1      58353-MAH  Female   45     Yes    Maharashtra                   14
# 2      25063-WES    Male   51      No    West Bengal                    4
# 3      59787-KAR    Male   79      No      Karnataka                    3
# 4      28544-TAM  Female   80      No     Tamil Nadu                    3
# ...          ...     ...  ...     ...            ...                  ...
# 6413   43397-UTT  Female   41      No  Uttar Pradesh                    6
# 6414   22240-HAR    Male   51     Yes        Haryana                    0
# 6415   78682-KER  Female   65     Yes         Kerala                   14
# 6416   17816-ODI    Male   23      No         Odisha                    2
# 6417   34476-TAM    Male   73      No     Tamil Nadu                   13
#
#       Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  6418 non-null   object
#  1   Gender                       6418 non-null   object
#  2   Age                          6418 non-null   int64
#  3   Married                      6418 non-null   object
#  4   State                        6418 non-null   object
#  5   Number_of_Referrals          6418 non-null   int64
#  6   Tenure_in_Months             6418 non-null   int64
#  7   Value_Deal                   6418 non-null   object
#  8   Phone_Service                6418 non-null   object
#  9   Multiple_Lines               6418 non-null   object
#  10  Internet_Service             6418 non-null   object
#  11  Internet_Type                6418 non-null   object
#  12  Online_Security              6418 non-null   object
# ...

# %%
data['Churn_Reason']=data['Churn_Reason'].fillna('Didn\'t leave')

# %%
data
# Out:
#      Customer_ID  Gender  Age Married          State  Number_of_Referrals  \
# 0      19877-DEL    Male   35      No          Delhi                    7
# 1      58353-MAH  Female   45     Yes    Maharashtra                   14
# 2      25063-WES    Male   51      No    West Bengal                    4
# 3      59787-KAR    Male   79      No      Karnataka                    3
# 4      28544-TAM  Female   80      No     Tamil Nadu                    3
# ...          ...     ...  ...     ...            ...                  ...
# 6413   43397-UTT  Female   41      No  Uttar Pradesh                    6
# 6414   22240-HAR    Male   51     Yes        Haryana                    0
# 6415   78682-KER  Female   65     Yes         Kerala                   14
# 6416   17816-ODI    Male   23      No         Odisha                    2
# 6417   34476-TAM    Male   73      No     Tamil Nadu                   13
#
#       Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  6418 non-null   object
#  1   Gender                       6418 non-null   object
#  2   Age                          6418 non-null   int64
#  3   Married                      6418 non-null   object
#  4   State                        6418 non-null   object
#  5   Number_of_Referrals          6418 non-null   int64
#  6   Tenure_in_Months             6418 non-null   int64
#  7   Value_Deal                   6418 non-null   object
#  8   Phone_Service                6418 non-null   object
#  9   Multiple_Lines               6418 non-null   object
#  10  Internet_Service             6418 non-null   object
#  11  Internet_Type                6418 non-null   object
#  12  Online_Security              6418 non-null   object
# ...

# %%
data.to_csv('processed_customer_data.csv',index=False)

# %%
data['Customer_Status'].value_counts()
# Out:
# Customer_Status
# Stayed     4275
# Churned    1732
# Joined      411
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
label_columns=['Gender', 'Married', 'State', 'Value_Deal', 'Phone_Service', 'Multiple_Lines',
                 'Internet_Service', 'Internet_Type', 'Online_Security', 'Online_Backup',
                 'Device_Protection_Plan', 'Premium_Support', 'Streaming_TV', 'Streaming_Movies',
                 'Streaming_Music', 'Unlimited_Data', 'Contract', 'Paperless_Billing', 'Payment_Method',
                 'Churn_Reason']

# %%
label_columns=['Gender', 'Married', 'State', 'Value_Deal', 'Phone_Service', 'Multiple_Lines',
                 'Internet_Service', 'Internet_Type', 'Online_Security', 'Online_Backup',
                 'Device_Protection_Plan', 'Premium_Support', 'Streaming_TV', 'Streaming_Movies',
                 'Streaming_Music', 'Unlimited_Data', 'Contract', 'Paperless_Billing', 'Payment_Method',
                 'Churn_Reason']
label_encoder=LabelEncoder()
for column in label_columns:
    data[column]=label_encoder.fit_transform(data[column])

# %%
X=data.drop(columns=['Customer_ID', 'Customer_Status', 'Churn_Category', 'Churn_Reason'])
Y=data['Customer_Status'].map(lambda x:1 if x=='Churned' else 0)
Y.value_counts()
# Out:
# Customer_Status
# 0    4686
# 1    1732
# Name: count, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)

# %%
model=RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
Y_pred=model.predict(X_test)

# %%
accuracy=accuracy_score(Y_test, Y_pred)
round(accuracy*100,2)
# Out:
# 81.39

# %%
cm=confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm,annot=True,fmt='.2f',xticklabels=['Not Churned','Churned'],yticklabels=['Not Churned','Churned'])
plt.show()

# %%
print('Classification Matrix')
print(classification_report(Y_test, Y_pred))
# Out:
# Classification Matrix
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88       937
#            1       0.68      0.58      0.63       347
#
#     accuracy                           0.81      1284
#    macro avg       0.77      0.74      0.75      1284
# weighted avg       0.81      0.81      0.81      1284

# %%
importance=model.feature_importances_
features=X.columns
feature_df=pd.DataFrame({'feature':features,'importance':importance})
feature_df=feature_df.sort_values('importance', ascending=False)
sns.barplot(data=feature_df,x='importance',y='feature',hue='importance',palette='rainbow')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
